# %%
import os
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
from PIL import Image
from urllib.parse import urljoin, unquote
from io import BytesIO
import re
import json

# The URL of the webpage you want to scrape
url = 'https://en.wikipedia.org/wiki/India'

# Folder where the images and their alt texts will be stored
images_folder = 'images_india'
os.makedirs(images_folder, exist_ok=True)

# Use requests to fetch the content of the URL
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

# Create a Markdown file to store the scraped text
with open('scraped_content_india.md', 'w', encoding='utf-8') as md_file:
    for element in soup.find_all(['p', 'h1', 'h2', 'h3']):
        # Assuming you want to capture paragraphs and headers
        if element.name.startswith('h'):
            md_file.write(f"\n# {element.get_text()}\n\n")  # Header with markdown format
        else:
            md_file.write(f"{element.get_text()}\n\n")  # Paragraph

#to download the image and store the alt text/related text of the image

titles_set = set()
images_info = []
for img_tag in soup.find_all('img'):

    img_url = urljoin(url, img_tag['src'])
    img_response = requests.get(img_url)

    # Get the alt text
    alt_text = img_tag.get('alt')
    if not alt_text:  # Checks if alt_text is None or empty
        alt_text = " "
        # Use the 'src' attribute as the fallback
        # src_text = img_tag.get('src')
        # srcset_text = img_tag.get('srcset')
        # if not src_text:
        #     alt_text = srcset_text
        #     if not srcset_text:
        #         alt_text = " "
        # else:
        #     alt_text = src_text
        # # if (srcset_text and src_text):
        # #     alt_text = src_text + " " + srcset_text
        # print(alt_text)

    title = img_tag.get('title')
    if not title:
        image_name = os.path.basename(img_url)
        clean_title = re.sub(r'\d+px', '', unquote(os.path.splitext(image_name)[0]))
        title = clean_title.replace('_', ' ').replace('-', ' ').strip()
        # If the title ends with '.svg', remove it
        if title.endswith('.svg'):
            title = title[:-4]
    else:
        image_name = os.path.basename(img_url)

    #print(title)
    # Ensure title uniqueness
    original_title = title
    count = 1
    while title in titles_set:
        count += 1
        title = f"{original_title} ({count})"
    titles_set.add(title)

    image_name = os.path.basename(img_url)

    data = {
        "title": title,
        "url": image_name,
        "text": alt_text
    }

    images_info.append(data)

    image_path = os.path.join(images_folder, image_name)
    with open(image_path, 'wb') as img_file:
        img_file.write(img_response.content)

    #saving the alt text in a separate file with the same name but .txt extension
    alt_text_path = os.path.join(images_folder, f"{os.path.splitext(image_name)[0]}.txt")
    with open(alt_text_path, 'w', encoding='utf-8') as text_file:
        text_file.write(alt_text)

with open('images_info.json', 'w', encoding='utf-8') as json_file:
    json.dump(images_info, json_file, indent=4, ensure_ascii=False)

# %%
# !zip -r images_india.zip images_india/
# Out:
#   adding: images_india/ (stored 0%)
#   adding: images_india/23px-Flag_of_Iran.svg.png (deflated 6%)
#   adding: images_india/27px-Wikibooks-logo.svg.png (stored 0%)
#   adding: images_india/23px-Flag_of_Cambodia.svg.txt (stored 0%)
#   adding: images_india/220px-Women_at_work%2C_Gujarat_%28cropped%29.txt (stored 0%)
#   adding: images_india/23px-Flag_of_Kyrgyzstan.svg.txt (stored 0%)
#   adding: images_india/23px-Flag_of_Belarus.svg.txt (stored 0%)
#   adding: images_india/23px-Flag_of_Iraq.svg.png (deflated 9%)
#   adding: images_india/180px-Nehru_gandhi.txt (stored 0%)
#   adding: images_india/208px-Rashtrapati_Bhavan_Wide_New_Delhi_India.txt (stored 0%)
#   adding: images_india/208px-Jawaharlal_Nehru%2C_Nasser_and_Tito_at_the_Conference_of_Non-Aligned_Nations_held_in_Belgrade.txt (stored 0%)
#   adding: images_india/440px-Sachin_Tendulkar_about_to_score_14000th_run_in_test_cricket.jpg (deflated 2%)
#   adding: images_india/23px-Flag_of_Uzbekistan.svg.txt (stored 0%)
#   adding: images_india/152px-Qutb_minar_ruins.jpg (deflated 3%)
#   adding: images_india/23px-Flag_of_Turkmenistan.svg.png (deflated 5%)
#   adding: images_india/474px-Elephanta_Caves_%2827804449706%29_%28cropped%29.jpg (deflated 0%)
#   adding: images_india/208px-Cherry_Resort_inside_Temi_Tea_Garden%2C_Namchi%2C_Sikkim.jpg (deflated 3%)
#   adding: images_india/208px-Cherry_Resort_inside_Temi_Tea_Garden%2C_Namchi%2C_Sikkim.txt (stored 0%)
#   adding: images_india/152px-Gopuram_Corner_View_of_Thanjavur_Brihadeeswara_Temple..txt (stored 0%)
#   adding: images_india/238px-Aks_The_Reflection_Taj_Mahal.txt (stored 0%)
#   adding: images_india/start?type=1x1 (deflated 7%)
#   adding: images_india/21px-Flag_of_Israel.svg.txt (stored 0%)
#   adding: images_india/270px-Axis_axis_%28Nagarhole%2C_2010%29.jpg (deflated 1%)
#   adding: images_india/23px-Flag_of_Mongolia.svg.png (deflated 9%)
#   adding: images_india/23px-Flag_of_Sri_Lanka.svg.png (deflated 4%)
#   adding: images_india/80px-South_Asia_%28orthographic_projection%29_without_national_boundaries.svg.png (deflated 3%)
#   adding: images_india/220px-Battle_at_Lanka%2C_Ramayana%2C_Udaipur%2C_1649-53.txt (stored 0%)
#   adding: images_india/220px-Cave_26%2C_Ajanta.jpg (deflated 2%)
#   adding: images_india/440px-Sachin_Tendulkar_about_to_score_14000th_run_in_test_cricket.txt (stored 0%)
#   adding: images_india/start?type=1x1.txt (stored 0%)
#   adding: images_india/23px-Flag_of_Syria.svg.png (deflated 12%)
#   adding: images_india/23px-Flag_of_the_United_Arab_Emirates.svg.png (deflated 16%)
#   adding: images_india/23px-Flag_of_Saudi_Arabia.svg.txt (stored 0%)
#   adding: images_india/22px-Flag_of_Brazil.svg.png (deflated 5%)
#   adding: images_india/212px-Jahangir_Receives_Prince_Khurram_at_Ajmer_on_His_Return_from_the_Mewar_Campaign.txt (stored 0%)
#   adding: images_india/208px-Modi_Nieto_Mexico_June_2016.txt (stored 0%)
#   adding: images_india/27px-Wikivoyage-Logo-v3-icon.svg.png (deflated 18%)
#   adding: images_india/23px-Flag_of_the_People%27s_Republic_of_China.svg.txt (stored 0%)
#   adding: images_india/23px-Flag_of_Myanmar.svg.png (deflated 7%)
#   adding: images_india/27px-Wiktionary-logo-v2.svg.png (stored 0%)
#   adding: images_india/208px-Barack_Obama_at_Parliament_of_India_in_New_Delhi_addressing_Joint_session_of_both_houses_2010.txt (stored 0%)
#   adding: images_india/23px-Flag_of_Kazakhstan.svg.png (deflated 5%)
#   adding: images_india/wikipedia-tagline-en.txt (stored 0%)
#   adding: images_india/23px-Flag_of_Tajikistan.svg.txt (stored 0%)
#   adding: images_india/16px-Symbol_portal_class.svg.png (deflated 6%)
#   adding: images_india/208px-Rajagopal_speaking_to_25%2C000_people%2C_Janadesh_2007%2C_India.txt (stored 0%)
#   adding: images_india/250px-India_%28orthographic_projection%29.svg.txt (deflated 7%)
#   adding: images_india/208px-Jawaharlal_Nehru%2C_Nasser_and_Tito_at_the_Conference_of_Non-Aligned_Nations_held_in_Belgrade.jpg (deflated 0%)
#   adding: images_india/330px-Political_map_of_India_EN.svg.png (deflated 0%)
#   adding: images_india/232px-India_School.txt (stored 0%)
#   adding: images_india/239px-MET_DT5237_%28cropped%29.txt (deflated 5%)
#   adding: images_india/208px-Female_health_workers_in_India_%2834332433890%29.jpg (deflated 0%)
#   adding: images_india/23px-Flag_of_the_Taliban.svg.png (deflated 9%)
#   adding: images_india/408px-Unknown%2C_Kangra%2C_India_-_Krishna_Fluting_to_the_Milkmaids_-_Google_Art_Project.txt (stored 0%)
#   adding: images_india/168px-South_Indian_Thali_Cropped.txt (stored 0%)
#   adding: images_india/100px-Asia_%28orthographic_projection%29.svg.png (deflated 1%)
#   adding: images_india/wikipedia.txt (stored 0%)
#   adding: images_india/23px-Flag_of_Russia.svg.txt (stored 0%)
#   adding: images_india/250px-India_%28orthographic_projection%29.svg.png (deflated 2%)
#   adding: images_india/20px-Commons-logo.svg.txt (stored 0%)
#   adding: images_india/20px-Extended-protection-shackle.svg.txt (stored 0%)
#   adding: images_india/23px-Flag_of_East_Timor.svg.png (deflated 8%)
#   adding: images_india/168px-Kuchipudi_Performer_DS.jpg (deflated 19%)
#   adding: images_india/208px-Sikh_pilgrim_at_the_Golden_Temple_%28Harmandir_Sahib%29_in_Amritsar%2C_India.txt (stored 0%)
#   adding: images_india/27px-Wikiversity_logo_2017.svg.txt (stored 0%)
#   adding: images_india/11px-Increase2.svg.png (deflated 15%)
#   adding: images_india/220px-Cave_26%2C_Ajanta.txt (stored 0%)
#   adding: images_india/23px-Flag_of_Azerbaijan.svg.png (deflated 11%)
#   adding: images_india/168px-Strolling_Shoppers_in_Paltan_Bazaar.jpg (deflated 0%)
#   adding: images_india/408px-Unknown%2C_Kangra%2C_India_-_Krishna_Fluting_to_the_Milkmaids_-_Google_Art_Project.jpg (deflated 1%)
#   adding: images_india/244px-Maharajah_Ramanuj_Pratap_Singh_Deo_with_cheetah_kill_1948_BNHS.jpg (deflated 0%)
#   adding: images_india/239px-MET_DT5237_%28cropped%29.jpg (deflated 0%)
#   adding: images_india/208px-Sikh_pilgrim_at_the_Golden_Temple_%28Harmandir_Sahib%29_in_Amritsar%2C_India.jpg (deflated 2%)
#   adding: images_india/23px-Flag_of_Egypt.svg.txt (stored 0%)
#   adding: images_india/208px-Muslims_praying_in_mosque_in_Srinagar%2C_Kashmir.jpg (deflated 0%)
#   adding: images_india/23px-Flag_of_Russia.svg.png (deflated 16%)
#   adding: images_india/23px-Flag_of_Pakistan.svg.txt (stored 0%)
#   adding: images_india/23px-Flag_of_Kyrgyzstan.svg.png (deflated 9%)
#   adding: images_india/208px-Modi_Nieto_Mexico_June_2016.jpg (deflated 0%)
#   adding: images_india/23px-Flag_of_Bahrain.svg.png (deflated 11%)
#   adding: images_india/27px-Wikinews-logo.svg.png (stored 0%)
#   adding: images_india/wikipedia-wordmark-en.txt (stored 0%)
#   adding: images_india/16px-Gnome-globe.svg.txt (stored 0%)
#   adding: images_india/220px-Plowing_the_land_in_India_-_modern_and_traditional.txt (stored 0%)
#   adding: images_india/23px-Flag_of_Qatar.svg.png (deflated 16%)
#   adding: images_india/23px-Flag_of_Kuwait.svg.txt (stored 0%)
#   adding: images_india/23px-Flag_of_Maldives.svg.txt (stored 0%)
#   adding: images_india/11px-Increase_Neutral.svg.png (deflated 12%)
#   adding: images_india/20px-Extended-protection-shackle.svg.png (deflated 19%)
#   adding: images_india/23px-Flag_of_the_Taliban.svg.txt (stored 0%)
#   adding: images_india/wikipedia-tagline-en.svg (deflated 66%)
#   adding: images_india/488px-Bangalore_Panorama_edit1.jpg (deflated 0%)
#   adding: images_india/168px-Odia_Mutton_Curry_%28Mansha_Tarkari%29_Rotated.jpg (deflated 0%)
#   adding: images_india/27px-Wikinews-logo.svg.txt (stored 0%)
#   adding: images_india/270px-Panthera_tigris_tigris_Tidoba_20150306.jpg (deflated 1%)
#   adding: images_india/23px-Wikiquote-logo.svg.png (deflated 10%)
#   adding: images_india/11px-Increase_Neutral.svg.txt (stored 0%)
#   adding: images_india/60px-Emblem_of_India.svg.png (stored 0%)
#   adding: images_india/23px-Flag_of_Ethiopia.svg.png (deflated 7%)
#   adding: images_india/23px-Flag_of_South_Africa.svg.png (deflated 5%)
#   adding: images_india/324px-Bhutesvara_Yakshis_Mathura_reliefs_2nd_century_CE_front.jpg (deflated 1%)
#   adding: images_india/168px-Strolling_Shoppers_in_Paltan_Bazaar.txt (stored 0%)
#   adding: images_india/23px-Flag_of_Turkey.svg.txt (stored 0%)
#   adding: images_india/23px-Flag_of_Iran.svg.txt (stored 0%)
#   adding: images_india/23px-Flag_of_Tajikistan.svg.png (deflated 11%)
#   adding: images_india/16px-Openstreetmap_logo.svg.txt (stored 0%)
#   adding: images_india/23px-Flag_of_Kazakhstan.svg.txt (stored 0%)
#   adding: images_india/23px-Flag_of_Myanmar.svg.txt (stored 0%)
#   adding: images_india/12px-Flag_of_Nepal.svg.png (deflated 5%)
#   adding: images_india/195px-India_1835_2_Mohurs.jpg (deflated 3%)
#   adding: images_india/164px-British_Indian_Empire_1909_Imperial_Gazetteer_of_India.jpg (deflated 2%)
#   adding: images_india/112px-Water_pump%2C_Varanasi_%2815563170660%29_Cropped.txt (stored 0%)
#   adding: images_india/20px-Cscr-featured.svg.png (deflated 0%)
#   adding: images_india/152px-Qutb_minar_ruins.txt (stored 0%)
#   adding: images_india/100px-Asia_%28orthographic_projection%29.svg.txt (stored 0%)
#   adding: images_india/232px-India_School.jpg (deflated 1%)
#   adding: images_india/324px-Bhutesvara_Yakshis_Mathura_reliefs_2nd_century_CE_front.txt (stored 0%)
#   adding: images_india/23px-Flag_of_Turkmenistan.svg.txt (stored 0%)
#   adding: images_india/23px-Flag_of_Bangladesh.svg.png (deflated 10%)
#   adding: images_india/208px-Rashtrapati_Bhavan_Wide_New_Delhi_India.jpg (deflated 0%)
#   adding: images_india/26px-Wikisource-logo.svg.png (stored 0%)
#   adding: images_india/27px-Wikibooks-logo.svg.txt (stored 0%)
#   adding: images_india/poweredby_mediawiki_88x31.txt (stored 0%)
#   adding: images_india/23px-Flag_of_Sri_Lanka.svg.txt (stored 0%)
#   adding: images_india/208px-Interior_of_San_Thome_Basilica.jpg (deflated 2%)
#   adding: images_india/168px-South_Indian_Thali_Cropped.jpg (deflated 0%)
#   adding: images_india/180px-Nehru_gandhi.jpg (deflated 3%)
#   adding: images_india/26px-Wikisource-logo.svg.txt (stored 0%)
#   adding: images_india/23px-Flag_of_Syria.svg.txt (stored 0%)
#   adding: images_india/208px-Barack_Obama_at_Parliament_of_India_in_New_Delhi_addressing_Joint_session_of_both_houses_2010.jpg (deflated 3%)
#   adding: images_india/208px-Rajagopal_speaking_to_25%2C000_people%2C_Janadesh_2007%2C_India.jpg (deflated 2%)
#   adding: images_india/23px-Flag_of_Bahrain.svg.txt (stored 0%)
#   adding: images_india/208px-Female_health_workers_in_India_%2834332433890%29.txt (stored 0%)
#   adding: images_india/27px-Wikivoyage-Logo-v3-icon.svg.txt (stored 0%)
#   adding: images_india/220px-47_Raika_School_-_eating_together_%283384824242%29.txt (stored 0%)
#   adding: images_india/21px-Flag_of_India.svg.png (deflated 10%)
#   adding: images_india/23px-Flag_of_Kuwait.svg.png (deflated 12%)
#   adding: images_india/208px-Indian_Air_Force_contingent_as_a_part_of_the_Bastille_Day_Parade_of_France%2C_in_Paris_on_July_14%2C_2009.txt (stored 0%)
#   adding: images_india/212px-Jahangir_Receives_Prince_Khurram_at_Ajmer_on_His_Return_from_the_Mewar_Campaign.jpg (deflated 0%)
#   adding: images_india/220px-47_Raika_School_-_eating_together_%283384824242%29.jpg (deflated 0%)
#   adding: images_india/125px-Flag_of_India.svg.png (stored 0%)
#   adding: images_india/16px-Symbol_category_class.svg.png (deflated 7%)
#   adding: images_india/208px-Tungabhadra_River_and_Coracle_Boats.txt (stored 0%)
#   adding: images_india/23px-Flag_of_Uzbekistan.svg.png (deflated 9%)
#   adding: images_india/23px-Flag_of_Pakistan.svg.png (deflated 8%)
#   adding: images_india/60px-Emblem_of_India.svg.txt (deflated 19%)
#   adding: images_india/wikimedia-button.png (stored 0%)
#   adding: images_india/220px-ILRI%2C_Stevie_Mann_-_Villager_and_calf_share_milk_from_cow_in_Rajasthan%2C_India.txt (stored 0%)
#   adding: images_india/23px-Flag_of_Bangladesh.svg.txt (stored 0%)
#   adding: images_india/112px-Water_pump%2C_Varanasi_%2815563170660%29_Cropped.jpg (deflated 0%)
#   adding: images_india/220px-Plowing_the_land_in_India_-_modern_and_traditional.jpg (deflated 0%)
#   adding: images_india/208px-Parked_boats_at_Anjarle_Creek.txt (stored 0%)
#   adding: images_india/238px-Aks_The_Reflection_Taj_Mahal.jpg (deflated 2%)
#   adding: images_india/195px-India_1835_2_Mohurs.txt (stored 0%)
#   adding: images_india/23px-Flag_of_Iraq.svg.txt (stored 0%)
#   adding: images_india/488px-Bangalore_Panorama_edit1.txt (stored 0%)
#   adding: images_india/270px-Axis_axis_%28Nagarhole%2C_2010%29.txt (deflated 15%)
#   adding: images_india/20px-Commons-logo.svg.png (deflated 20%)
#   adding: images_india/208px-Parked_boats_at_Anjarle_Creek.jpg (deflated 3%)
#   adding: images_india/149px-Agra_Fort_DistantTaj.txt (stored 0%)
#   adding: images_india/12px-Flag_of_Nepal.svg.txt (stored 0%)
#   adding: images_india/168px-South_Asian_Language_Families.txt (stored 0%)
#   adding: images_india/16px-Openstreetmap_logo.svg.png (deflated 3%)
#   adding: images_india/244px-Maharajah_Ramanuj_Pratap_Singh_Deo_with_cheetah_kill_1948_BNHS.txt (deflated 31%)
#   adding: images_india/11px-Increase2.svg.txt (stored 0%)
#   adding: images_india/19px-Asia_%28orthographic_projection%29.svg.png (deflated 4%)
#   adding: images_india/168px-Kuchipudi_Performer_DS.txt (stored 0%)
#   adding: images_india/10px-OOjs_UI_icon_edit-ltr-progressive.svg.png (deflated 14%)
#   adding: images_india/23px-Flag_of_Mongolia.svg.txt (stored 0%)
#   adding: images_india/164px-British_Indian_Empire_1909_Imperial_Gazetteer_of_India.txt (stored 0%)
#   adding: images_india/11px-Increase_Negative.svg.txt (stored 0%)
#   adding: images_india/23px-Flag_of_Egypt.svg.png (deflated 11%)
#   adding: images_india/80px-South_Asia_%28orthographic_projection%29_without_national_boundaries.svg.txt (stored 0%)
#   adding: images_india/220px-Battle_at_Lanka%2C_Ramayana%2C_Udaipur%2C_1649-53.jpg (deflated 0%)
#   adding: images_india/23px-Flag_of_Saudi_Arabia.svg.png (deflated 8%)
#   adding: images_india/23px-Flag_of_Algeria.svg.png (deflated 8%)
#   adding: images_india/23px-Flag_of_Algeria.svg.txt (stored 0%)
#   adding: images_india/wikipedia.png (stored 0%)
#   adding: images_india/220px-ILRI%2C_Stevie_Mann_-_Villager_and_calf_share_milk_from_cow_in_Rajasthan%2C_India.jpg (deflated 0%)
#   adding: images_india/wikimedia-button.txt (stored 0%)
#   adding: images_india/poweredby_mediawiki_88x31.png (stored 0%)
#   adding: images_india/220px-Women_at_work%2C_Gujarat_%28cropped%29.jpg (deflated 2%)
#   adding: images_india/208px-Tungabhadra_River_and_Coracle_Boats.JPG (deflated 3%)
#   adding: images_india/20px-Cscr-featured.svg.txt (stored 0%)
#   adding: images_india/23px-Flag_of_the_People%27s_Republic_of_China.svg.png (deflated 10%)
#   adding: images_india/208px-Muslims_praying_in_mosque_in_Srinagar%2C_Kashmir.txt (stored 0%)
#   adding: images_india/270px-Panthera_tigris_tigris_Tidoba_20150306.txt (deflated 4%)
#   adding: images_india/23px-Flag_of_Armenia.svg.txt (stored 0%)
#   adding: images_india/23px-Flag_of_Maldives.svg.png (deflated 11%)
#   adding: images_india/23px-Flag_of_Belarus.svg.png (deflated 10%)
#   adding: images_india/268px-Shiva_as_Lord_of_the_Dance_%28Nataraja%29.txt (deflated 4%)
#   adding: images_india/wikipedia-wordmark-en.svg (deflated 58%)
#   adding: images_india/27px-Wiktionary-logo-v2.svg.txt (stored 0%)
#   adding: images_india/16px-Symbol_portal_class.svg.txt (stored 0%)
#   adding: images_india/27px-Wikiversity_logo_2017.svg.png (deflated 19%)
#   adding: images_india/23px-Flag_of_Ethiopia.svg.txt (stored 0%)
#   adding: images_india/23px-Flag_of_South_Africa.svg.txt (stored 0%)
#   adding: images_india/16px-Symbol_category_class.svg.txt (stored 0%)
#   adding: images_india/19px-Asia_%28orthographic_projection%29.svg.txt (stored 0%)
#   adding: images_india/23px-Flag_of_Turkey.svg.png (deflated 8%)
#   adding: images_india/23px-Flag_of_India.svg.txt (stored 0%)
#   adding: images_india/152px-Gopuram_Corner_View_of_Thanjavur_Brihadeeswara_Temple..JPG (deflated 0%)
#   adding: images_india/23px-Flag_of_the_United_Arab_Emirates.svg.txt (stored 0%)
#   adding: images_india/11px-Increase_Negative.svg.png (deflated 17%)
#   adding: images_india/208px-Filles_jouant_%C3%A0_la_marelle%2C_Jaura%2C_Inde.txt (stored 0%)
#   adding: images_india/474px-Elephanta_Caves_%2827804449706%29_%28cropped%29.txt (stored 0%)
#   adding: images_india/23px-Wikiquote-logo.svg.txt (stored 0%)
#   adding: images_india/22px-Flag_of_Brazil.svg.txt (stored 0%)
#   adding: images_india/330px-Political_map_of_India_EN.svg.txt (stored 0%)
#   adding: images_india/23px-Flag_of_East_Timor.svg.txt (stored 0%)
#   adding: images_india/208px-Indian_Air_Force_contingent_as_a_part_of_the_Bastille_Day_Parade_of_France%2C_in_Paris_on_July_14%2C_2009.jpg (deflated 2%)
#   adding: images_india/208px-Filles_jouant_%C3%A0_la_marelle%2C_Jaura%2C_Inde.jpg (deflated 0%)
#   adding: images_india/23px-Flag_of_Armenia.svg.png (deflated 16%)
#   adding: images_india/23px-Flag_of_Cambodia.svg.png (deflated 7%)
#   adding: images_india/23px-Flag_of_India.svg.png (deflated 12%)
#   adding: images_india/149px-Agra_Fort_DistantTaj.JPG (deflated 1%)
#   adding: images_india/23px-Flag_of_Qatar.svg.txt (stored 0%)
#   adding: images_india/21px-Flag_of_India.svg.txt (stored 0%)
#   adding: images_india/125px-Flag_of_India.svg.txt (deflated 28%)
#   adding: images_india/21px-Flag_of_Israel.svg.png (deflated 11%)
#   adding: images_india/268px-Shiva_as_Lord_of_the_Dance_%28Nataraja%29.jpg (deflated 0%)
#   adding: images_india/16px-Gnome-globe.svg.png (deflated 1%)
#   adding: images_india/10px-OOjs_UI_icon_edit-ltr-progressive.svg.txt (stored 0%)
#   adding: images_india/168px-Odia_Mutton_Curry_%28Mansha_Tarkari%29_Rotated.txt (stored 0%)
#   adding: images_india/23px-Flag_of_Azerbaijan.svg.txt (stored 0%)
#   adding: images_india/168px-South_Asian_Language_Families.png (deflated 1%)
#   adding: images_india/208px-Interior_of_San_Thome_Basilica.txt (stored 0%)

# %%
from google.colab import files
files.download('images_india.zip')

# %%
import requests

# The base URL of the website
base_url = 'https://igod.gov.in/'

# Construct the URL for the robots.txt file
robots_url = f'{base_url}/robots.txt'

# Fetch the content of the robots.txt file
response = requests.get(robots_url)

if response.status_code == 200:
    # Print the contents of the robots.txt file
    print(response.text)
else:
    print("Failed to retrieve robots.txt")
# Out:
# User-agent: *
# Disallow:/docs/
